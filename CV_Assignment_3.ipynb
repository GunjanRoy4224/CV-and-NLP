# %% [markdown]
# <a href="https://colab.research.google.com/github/GunjanRoy4224/CV-and-NLP/blob/main/CV_Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment - 3**
# ## **Fine-tuning a Pretrained ResNet Model for Image Classification**
#
# In this assignment, we will explore the concept of transfer learning by fine-tuning a pretrained ResNet model for the task of image classification. ResNet, or Residual Network, is a deep convolutional neural network architecture that has achieved state-of-the-art performance on a variety of visual recognition tasks. Pretrained models are models that have been previously trained on large datasets, such as ImageNet, and can serve as a starting point for new tasks by leveraging learned features. By fine-tuning the pretrained ResNet, we aim to adapt its feature representations to a new dataset, improving both training efficiency and model performance. This process involves adjusting the model’s final layers to suit the specific classification problem, while retaining the learned features from earlier layers. At the end we compare the prformance of the pre-trained model with that of the fine-tuned model.

# %% [markdown]
# ====================================================================================================

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 1**
# 1) <blue>**torch**</blue>: This imports the <green>**PyTorch library**</green>, which is essential for building and training neural networks.
# 2) <blue>**torch.nn**</blue>: Imports the <green>**neural network module**</green> of PyTorch, which contains various layers and loss functions used to build models.
# 3) <blue>**torch.optim**</blue>: This imports the <green>**optimization algorithms**</green> module, used for updating the model's weights based on the computed gradients during training.
# 4) <blue>**torchvision -> datasets, models, transforms**</blue>: Imports functions from <green>**Torchvision**</green> for accessing popular datasets, pre-trained models, and transformations for image preprocessing.
# 5) <blue>**torchvision.utils -> make_grid**</blue>: This function is used to <green>**visualize multiple images**</green> in a grid format, useful for displaying image batches.
# 6) <blue>**torch.utils.data -> DataLoader**</blue>: Imports the <green>**DataLoader**</green> class, which allows for efficient loading and batching of datasets during training and testing.
# 7) <blue>**matplotlib.pyplot**</blue>: This imports <green>**Matplotlib**</green>, which is used for plotting and visualizing images or training metrics such as loss and accuracy.
# 8) <blue>**numpy**</blue>: Imports <green>**NumPy**</green> for handling arrays and performing numerical operations, which are often useful in preprocessing and analyzing data.
# 9) <blue>**time**</blue>: This allows tracking <green>**elapsed time**</green> during the training process, often used to measure performance.
# 10) <blue>**os**</blue>: Imports <green>**OS module**</green> to handle tasks like creating directories, managing file paths, or interacting with the file system.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torchvision.utils import make_grid
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import time
import os

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 2**
# 1) <blue>**device**</blue>: This variable checks if a <green>**CUDA-capable GPU**</green> is available; if so, it sets the device to GPU (cuda), otherwise, it falls back to the <green>**CPU**</green>.
# 2) <blue>**transforms.Compose**</blue>: This creates a series of <green>**transformations for training images**</green>, applied in the specified order to augment the data and prepare it for the model.
# 3) <blue>**transforms.Grayscale(num_output_channels=3)**</blue>: This transformation converts input images from grayscale to <green>**RGB**</green> by creating 3 output channels, which is necessary for models expecting RGB inputs.
# 4) <blue>**transforms.RandomResizedCrop(224)**</blue>: This randomly crops the input image to a size of <green>**224x224 pixels**</green>, introducing variation in the training data to improve model generalization.
# 5) <blue>**transforms.RandomHorizontalFlip()**</blue>: This randomly flips the image horizontally with a 50% chance, providing additional <green>**data augmentation**</green> for the training dataset.
# 6) <blue>**transforms.ToTensor()**</blue>: Converts the PIL image or NumPy array into a <green>**PyTorch tensor**</green>, which is the required input format for models.
# 7) <blue>**transforms.Normalize()**</blue>: This normalizes the tensor with mean and standard deviation values specified for each channel, helping the model to <green>**converge faster**</green> and perform better by ensuring the input data has a consistent scale.
# 8) <blue>**transforms.Resize(256)**</blue>: This resizes the input image to a height and width of <green>**256 pixels**</green>, ensuring consistency in input size before cropping.
# 9) <blue>**transforms.CenterCrop(224)**</blue>: This crops the center of the image to <green>**224x224 pixels**</green>, focusing on the most important part of the image for testing.

# %%
# Check if CUDA is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define the transformations for training and testing
transform_train = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),  # Convert grayscale to 3 channels (RGB)
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

transform_test = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),  # Convert grayscale to 3 channels (RGB)
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225)),
])

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 3**
# 1) This code outlines loading the <blue>**Caltech-256**</blue> dataset for <green>**image classification**</green>.
# 2) The <blue>**train_loader**</blue> and <blue>**test_loader**</blue> are used to load the datasets in batches of 32, with shuffling applied only to the training set.
#
# Note: The placeholders **"None"** need to be replaced with the correct dataset-loading code.

# %%
# !tar -xvf 256_ObjectCategories.tar
# Out:
# 256_ObjectCategories/
# 256_ObjectCategories/001.ak47/
# 256_ObjectCategories/001.ak47/001_0001.jpg
# 256_ObjectCategories/001.ak47/001_0002.jpg
# 256_ObjectCategories/001.ak47/001_0003.jpg
# 256_ObjectCategories/001.ak47/001_0004.jpg
# 256_ObjectCategories/001.ak47/001_0005.jpg
# 256_ObjectCategories/001.ak47/001_0006.jpg
# 256_ObjectCategories/001.ak47/001_0007.jpg
# 256_ObjectCategories/001.ak47/001_0008.jpg
# 256_ObjectCategories/001.ak47/001_0009.jpg
# 256_ObjectCategories/001.ak47/001_0010.jpg
# 256_ObjectCategories/001.ak47/001_0011.jpg
# 256_ObjectCategories/001.ak47/001_0012.jpg
# 256_ObjectCategories/001.ak47/001_0013.jpg
# 256_ObjectCategories/001.ak47/001_0014.jpg
# 256_ObjectCategories/001.ak47/001_0015.jpg
# 256_ObjectCategories/001.ak47/001_0016.jpg
# 256_ObjectCategories/001.ak47/001_0017.jpg
# 256_ObjectCategories/001.ak47/001_0018.jpg
# 256_ObjectCategories/001.ak47/001_0019.jpg
# 256_ObjectCategories/001.ak47/001_0020.jpg
# 256_ObjectCategories/001.ak47/001_0021.jpg
# 256_ObjectCategories/001.ak47/001_0022.jpg
# 256_ObjectCategories/001.ak47/001_0023.jpg
# 256_ObjectCategories/001.ak47/001_0024.jpg
# 256_ObjectCategories/001.ak47/001_0025.jpg
# 256_ObjectCategories/001.ak47/001_0026.jpg
# 256_ObjectCategories/001.ak47/001_0027.jpg
# 256_ObjectCategories/001.ak47/001_0028.jpg
# 256_ObjectCategories/001.ak47/001_0029.jpg
# 256_ObjectCategories/001.ak47/001_0030.jpg
# 256_ObjectCategories/001.ak47/001_0031.jpg
# 256_ObjectCategories/001.ak47/001_0032.jpg
# 256_ObjectCategories/001.ak47/001_0033.jpg
# 256_ObjectCategories/001.ak47/001_0034.jpg
# 256_ObjectCategories/001.ak47/001_0035.jpg
# 256_ObjectCategories/001.ak47/001_0036.jpg
# 256_ObjectCategories/001.ak47/001_0037.jpg
# 256_ObjectCategories/001.ak47/001_0038.jpg
# 256_ObjectCategories/001.ak47/001_0039.jpg
# 256_ObjectCategories/001.ak47/001_0040.jpg
# 256_ObjectCategories/001.ak47/001_0041.jpg
# 256_ObjectCategories/001.ak47/001_0042.jpg
# 256_ObjectCategories/001.ak47/001_0043.jpg
# 256_ObjectCategories/001.ak47/001_0044.jpg
# 256_ObjectCategories/001.ak47/001_0045.jpg
# 256_ObjectCategories/001.ak47/001_0046.jpg
# 256_ObjectCategories/001.ak47/001_0047.jpg
# 256_ObjectCategories/001.ak47/001_0048.jpg
# 256_ObjectCategories/001.ak47/001_0049.jpg
# 256_ObjectCategories/001.ak47/001_0050.jpg
# 256_ObjectCategories/001.ak47/001_0051.jpg
# 256_ObjectCategories/001.ak47/001_0052.jpg
# 256_ObjectCategories/001.ak47/001_0053.jpg
# 256_ObjectCategories/001.ak47/001_0054.jpg
# 256_ObjectCategories/001.ak47/001_0055.jpg
# 256_ObjectCategories/001.ak47/001_0056.jpg
# 256_ObjectCategories/001.ak47/001_0057.jpg
# 256_ObjectCategories/001.ak47/001_0058.jpg
# 256_ObjectCategories/001.ak47/001_0059.jpg
# 256_ObjectCategories/001.ak47/001_0060.jpg
# 256_ObjectCategories/001.ak47/001_0061.jpg
# 256_ObjectCategories/001.ak47/001_0062.jpg
# 256_ObjectCategories/001.ak47/001_0063.jpg
# 256_ObjectCategories/001.ak47/001_0064.jpg
# 256_ObjectCategories/001.ak47/001_0065.jpg
# 256_ObjectCategories/001.ak47/001_0066.jpg
# 256_ObjectCategories/001.ak47/001_0067.jpg
# 256_ObjectCategories/001.ak47/001_0068.jpg
# 256_ObjectCategories/001.ak47/001_0069.jpg
# 256_ObjectCategories/001.ak47/001_0070.jpg
# 256_ObjectCategories/001.ak47/001_0071.jpg
# 256_ObjectCategories/001.ak47/001_0072.jpg
# 256_ObjectCategories/001.ak47/001_0073.jpg
# 256_ObjectCategories/001.ak47/001_0074.jpg
# 256_ObjectCategories/001.ak47/001_0075.jpg
# 256_ObjectCategories/001.ak47/001_0076.jpg
# 256_ObjectCategories/001.ak47/001_0077.jpg
# 256_ObjectCategories/001.ak47/001_0078.jpg
# 256_ObjectCategories/001.ak47/001_0079.jpg
# 256_ObjectCategories/001.ak47/001_0080.jpg
# 256_ObjectCategories/001.ak47/001_0081.jpg
# 256_ObjectCategories/001.ak47/001_0082.jpg
# 256_ObjectCategories/001.ak47/001_0083.jpg
# 256_ObjectCategories/001.ak47/001_0084.jpg
# 256_ObjectCategories/001.ak47/001_0085.jpg
# 256_ObjectCategories/001.ak47/001_0086.jpg
# 256_ObjectCategories/001.ak47/001_0087.jpg
# 256_ObjectCategories/001.ak47/001_0088.jpg
# 256_ObjectCategories/001.ak47/001_0089.jpg
# 256_ObjectCategories/001.ak47/001_0090.jpg
# 256_ObjectCategories/001.ak47/001_0091.jpg
# 256_ObjectCategories/001.ak47/001_0092.jpg
# 256_ObjectCategories/001.ak47/001_0093.jpg
# 256_ObjectCategories/001.ak47/001_0094.jpg
# 256_ObjectCategories/001.ak47/001_0095.jpg
# 256_ObjectCategories/001.ak47/001_0096.jpg
# 256_ObjectCategories/001.ak47/001_0097.jpg
# 256_ObjectCategories/001.ak47/001_0098.jpg
# 256_ObjectCategories/002.american-flag/
# 256_ObjectCategories/002.american-flag/002_0001.jpg
# 256_ObjectCategories/002.american-flag/002_0002.jpg
# 256_ObjectCategories/002.american-flag/002_0003.jpg
# 256_ObjectCategories/002.american-flag/002_0004.jpg
# 256_ObjectCategories/002.american-flag/002_0005.jpg
# 256_ObjectCategories/002.american-flag/002_0006.jpg
# 256_ObjectCategories/002.american-flag/002_0007.jpg
# 256_ObjectCategories/002.american-flag/002_0008.jpg
# 256_ObjectCategories/002.american-flag/002_0009.jpg
# 256_ObjectCategories/002.american-flag/002_0010.jpg
# 256_ObjectCategories/002.american-flag/002_0011.jpg
# 256_ObjectCategories/002.american-flag/002_0012.jpg
# 256_ObjectCategories/002.american-flag/002_0013.jpg
# 256_ObjectCategories/002.american-flag/002_0014.jpg
# 256_ObjectCategories/002.american-flag/002_0015.jpg
# 256_ObjectCategories/002.american-flag/002_0016.jpg
# 256_ObjectCategories/002.american-flag/002_0017.jpg
# 256_ObjectCategories/002.american-flag/002_0018.jpg
# 256_ObjectCategories/002.american-flag/002_0019.jpg
# 256_ObjectCategories/002.american-flag/002_0020.jpg
# 256_ObjectCategories/002.american-flag/002_0021.jpg
# 256_ObjectCategories/002.american-flag/002_0022.jpg
# 256_ObjectCategories/002.american-flag/002_0023.jpg
# 256_ObjectCategories/002.american-flag/002_0024.jpg
# 256_ObjectCategories/002.american-flag/002_0025.jpg
# 256_ObjectCategories/002.american-flag/002_0026.jpg
# 256_ObjectCategories/002.american-flag/002_0027.jpg
# 256_ObjectCategories/002.american-flag/002_0028.jpg
# 256_ObjectCategories/002.american-flag/002_0029.jpg
# 256_ObjectCategories/002.american-flag/002_0030.jpg
# 256_ObjectCategories/002.american-flag/002_0031.jpg
# 256_ObjectCategories/002.american-flag/002_0032.jpg
# 256_ObjectCategories/002.american-flag/002_0033.jpg
# 256_ObjectCategories/002.american-flag/002_0034.jpg
# 256_ObjectCategories/002.american-flag/002_0035.jpg
# 256_ObjectCategories/002.american-flag/002_0036.jpg
# 256_ObjectCategories/002.american-flag/002_0037.jpg
# 256_ObjectCategories/002.american-flag/002_0038.jpg
# 256_ObjectCategories/002.american-flag/002_0039.jpg
# 256_ObjectCategories/002.american-flag/002_0040.jpg
# 256_ObjectCategories/002.american-flag/002_0041.jpg
# 256_ObjectCategories/002.american-flag/002_0042.jpg
# 256_ObjectCategories/002.american-flag/002_0043.jpg
# 256_ObjectCategories/002.american-flag/002_0044.jpg
# 256_ObjectCategories/002.american-flag/002_0045.jpg
# 256_ObjectCategories/002.american-flag/002_0046.jpg
# 256_ObjectCategories/002.american-flag/002_0047.jpg
# 256_ObjectCategories/002.american-flag/002_0048.jpg
# 256_ObjectCategories/002.american-flag/002_0049.jpg
# 256_ObjectCategories/002.american-flag/002_0050.jpg
# 256_ObjectCategories/002.american-flag/002_0051.jpg
# 256_ObjectCategories/002.american-flag/002_0052.jpg
# 256_ObjectCategories/002.american-flag/002_0053.jpg
# 256_ObjectCategories/002.american-flag/002_0054.jpg
# 256_ObjectCategories/002.american-flag/002_0055.jpg
# 256_ObjectCategories/002.american-flag/002_0056.jpg
# 256_ObjectCategories/002.american-flag/002_0057.jpg
# 256_ObjectCategories/002.american-flag/002_0058.jpg
# 256_ObjectCategories/002.american-flag/002_0059.jpg
# 256_ObjectCategories/002.american-flag/002_0060.jpg
# 256_ObjectCategories/002.american-flag/002_0061.jpg
# 256_ObjectCategories/002.american-flag/002_0062.jpg
# 256_ObjectCategories/002.american-flag/002_0063.jpg
# 256_ObjectCategories/002.american-flag/002_0064.jpg
# 256_ObjectCategories/002.american-flag/002_0065.jpg
# 256_ObjectCategories/002.american-flag/002_0066.jpg
# 256_ObjectCategories/002.american-flag/002_0067.jpg
# 256_ObjectCategories/002.american-flag/002_0068.jpg
# 256_ObjectCategories/002.american-flag/002_0069.jpg
# 256_ObjectCategories/002.american-flag/002_0070.jpg
# 256_ObjectCategories/002.american-flag/002_0071.jpg
# 256_ObjectCategories/002.american-flag/002_0072.jpg
# 256_ObjectCategories/002.american-flag/002_0073.jpg
# 256_ObjectCategories/002.american-flag/002_0074.jpg
# 256_ObjectCategories/002.american-flag/002_0075.jpg
# 256_ObjectCategories/002.american-flag/002_0076.jpg
# 256_ObjectCategories/002.american-flag/002_0077.jpg
# 256_ObjectCategories/002.american-flag/002_0078.jpg
# 256_ObjectCategories/002.american-flag/002_0079.jpg
# 256_ObjectCategories/002.american-flag/002_0080.jpg
# 256_ObjectCategories/002.american-flag/002_0081.jpg
# 256_ObjectCategories/002.american-flag/002_0082.jpg
# 256_ObjectCategories/002.american-flag/002_0083.jpg
# 256_ObjectCategories/002.american-flag/002_0084.jpg
# 256_ObjectCategories/002.american-flag/002_0085.jpg
# 256_ObjectCategories/002.american-flag/002_0086.jpg
# 256_ObjectCategories/002.american-flag/002_0087.jpg
# 256_ObjectCategories/002.american-flag/002_0088.jpg
# 256_ObjectCategories/002.american-flag/002_0089.jpg
# 256_ObjectCategories/002.american-flag/002_0090.jpg
# 256_ObjectCategories/002.american-flag/002_0091.jpg
# 256_ObjectCategories/002.american-flag/002_0092.jpg
# 256_ObjectCategories/002.american-flag/002_0093.jpg
# 256_ObjectCategories/002.american-flag/002_0094.jpg
# 256_ObjectCategories/002.american-flag/002_0095.jpg
# 256_ObjectCategories/002.american-flag/002_0096.jpg
# 256_ObjectCategories/002.american-flag/002_0097.jpg
# 256_ObjectCategories/003.backpack/
# 256_ObjectCategories/003.backpack/003_0001.jpg
# 256_ObjectCategories/003.backpack/003_0002.jpg
# 256_ObjectCategories/003.backpack/003_0003.jpg
# 256_ObjectCategories/003.backpack/003_0004.jpg
# 256_ObjectCategories/003.backpack/003_0005.jpg
# 256_ObjectCategories/003.backpack/003_0006.jpg
# 256_ObjectCategories/003.backpack/003_0007.jpg
# 256_ObjectCategories/003.backpack/003_0008.jpg
# 256_ObjectCategories/003.backpack/003_0009.jpg
# 256_ObjectCategories/003.backpack/003_0010.jpg
# 256_ObjectCategories/003.backpack/003_0011.jpg
# 256_ObjectCategories/003.backpack/003_0012.jpg
# 256_ObjectCategories/003.backpack/003_0013.jpg
# 256_ObjectCategories/003.backpack/003_0014.jpg
# 256_ObjectCategories/003.backpack/003_0015.jpg
# 256_ObjectCategories/003.backpack/003_0016.jpg
# 256_ObjectCategories/003.backpack/003_0017.jpg
# 256_ObjectCategories/003.backpack/003_0018.jpg
# 256_ObjectCategories/003.backpack/003_0019.jpg
# 256_ObjectCategories/003.backpack/003_0020.jpg
# 256_ObjectCategories/003.backpack/003_0021.jpg
# 256_ObjectCategories/003.backpack/003_0022.jpg
# 256_ObjectCategories/003.backpack/003_0023.jpg
# 256_ObjectCategories/003.backpack/003_0024.jpg
# 256_ObjectCategories/003.backpack/003_0025.jpg
# 256_ObjectCategories/003.backpack/003_0026.jpg
# 256_ObjectCategories/003.backpack/003_0027.jpg
# 256_ObjectCategories/003.backpack/003_0028.jpg
# 256_ObjectCategories/003.backpack/003_0029.jpg
# 256_ObjectCategories/003.backpack/003_0030.jpg
# 256_ObjectCategories/003.backpack/003_0031.jpg
# 256_ObjectCategories/003.backpack/003_0032.jpg
# 256_ObjectCategories/003.backpack/003_0033.jpg
# 256_ObjectCategories/003.backpack/003_0034.jpg
# 256_ObjectCategories/003.backpack/003_0035.jpg
# 256_ObjectCategories/003.backpack/003_0036.jpg
# 256_ObjectCategories/003.backpack/003_0037.jpg
# 256_ObjectCategories/003.backpack/003_0038.jpg
# 256_ObjectCategories/003.backpack/003_0039.jpg
# 256_ObjectCategories/003.backpack/003_0040.jpg
# 256_ObjectCategories/003.backpack/003_0041.jpg
# 256_ObjectCategories/003.backpack/003_0042.jpg
# 256_ObjectCategories/003.backpack/003_0043.jpg
# 256_ObjectCategories/003.backpack/003_0044.jpg
# 256_ObjectCategories/003.backpack/003_0045.jpg
# 256_ObjectCategories/003.backpack/003_0046.jpg
# 256_ObjectCategories/003.backpack/003_0047.jpg
# 256_ObjectCategories/003.backpack/003_0048.jpg
# 256_ObjectCategories/003.backpack/003_0049.jpg
# 256_ObjectCategories/003.backpack/003_0050.jpg
# 256_ObjectCategories/003.backpack/003_0051.jpg
# 256_ObjectCategories/003.backpack/003_0052.jpg
# 256_ObjectCategories/003.backpack/003_0053.jpg
# 256_ObjectCategories/003.backpack/003_0054.jpg
# 256_ObjectCategories/003.backpack/003_0055.jpg
# 256_ObjectCategories/003.backpack/003_0056.jpg
# 256_ObjectCategories/003.backpack/003_0057.jpg
# 256_ObjectCategories/003.backpack/003_0058.jpg
# 256_ObjectCategories/003.backpack/003_0059.jpg
# 256_ObjectCategories/003.backpack/003_0060.jpg
# 256_ObjectCategories/003.backpack/003_0061.jpg
# 256_ObjectCategories/003.backpack/003_0062.jpg
# 256_ObjectCategories/003.backpack/003_0063.jpg
# 256_ObjectCategories/003.backpack/003_0064.jpg
# 256_ObjectCategories/003.backpack/003_0065.jpg
# 256_ObjectCategories/003.backpack/003_0066.jpg
# 256_ObjectCategories/003.backpack/003_0067.jpg
# 256_ObjectCategories/003.backpack/003_0068.jpg
# 256_ObjectCategories/003.backpack/003_0069.jpg
# 256_ObjectCategories/003.backpack/003_0070.jpg
# 256_ObjectCategories/003.backpack/003_0071.jpg
# 256_ObjectCategories/003.backpack/003_0072.jpg
# 256_ObjectCategories/003.backpack/003_0073.jpg
# 256_ObjectCategories/003.backpack/003_0074.jpg
# 256_ObjectCategories/003.backpack/003_0075.jpg
# 256_ObjectCategories/003.backpack/003_0076.jpg
# 256_ObjectCategories/003.backpack/003_0077.jpg
# 256_ObjectCategories/003.backpack/003_0078.jpg
# 256_ObjectCategories/003.backpack/003_0079.jpg
# 256_ObjectCategories/003.backpack/003_0080.jpg
# 256_ObjectCategories/003.backpack/003_0081.jpg
# 256_ObjectCategories/003.backpack/003_0082.jpg
# 256_ObjectCategories/003.backpack/003_0083.jpg
# 256_ObjectCategories/003.backpack/003_0084.jpg
# 256_ObjectCategories/003.backpack/003_0085.jpg
# 256_ObjectCategories/003.backpack/003_0086.jpg
# 256_ObjectCategories/003.backpack/003_0087.jpg
# 256_ObjectCategories/003.backpack/003_0088.jpg
# 256_ObjectCategories/003.backpack/003_0089.jpg
# 256_ObjectCategories/003.backpack/003_0090.jpg
# 256_ObjectCategories/003.backpack/003_0091.jpg
# 256_ObjectCategories/003.backpack/003_0092.jpg
# 256_ObjectCategories/003.backpack/003_0093.jpg
# 256_ObjectCategories/003.backpack/003_0094.jpg
# 256_ObjectCategories/003.backpack/003_0095.jpg
# 256_ObjectCategories/003.backpack/003_0096.jpg
# 256_ObjectCategories/003.backpack/003_0097.jpg
# 256_ObjectCategories/003.backpack/003_0098.jpg
# 256_ObjectCategories/003.backpack/003_0099.jpg
# 256_ObjectCategories/003.backpack/003_0100.jpg
# 256_ObjectCategories/003.backpack/003_0101.jpg
# 256_ObjectCategories/003.backpack/003_0102.jpg
# 256_ObjectCategories/003.backpack/003_0103.jpg
# 256_ObjectCategories/003.backpack/003_0104.jpg
# 256_ObjectCategories/003.backpack/003_0105.jpg
# 256_ObjectCategories/003.backpack/003_0106.jpg
# 256_ObjectCategories/003.backpack/003_0107.jpg
# 256_ObjectCategories/003.backpack/003_0108.jpg
# 256_ObjectCategories/003.backpack/003_0109.jpg
# 256_ObjectCategories/003.backpack/003_0110.jpg
# 256_ObjectCategories/003.backpack/003_0111.jpg
# 256_ObjectCategories/003.backpack/003_0112.jpg
# 256_ObjectCategories/003.backpack/003_0113.jpg
# 256_ObjectCategories/003.backpack/003_0114.jpg
# 256_ObjectCategories/003.backpack/003_0115.jpg
# 256_ObjectCategories/003.backpack/003_0116.jpg
# 256_ObjectCategories/003.backpack/003_0117.jpg
# 256_ObjectCategories/003.backpack/003_0118.jpg
# 256_ObjectCategories/003.backpack/003_0119.jpg
# 256_ObjectCategories/003.backpack/003_0120.jpg
# 256_ObjectCategories/003.backpack/003_0121.jpg
# 256_ObjectCategories/003.backpack/003_0122.jpg
# 256_ObjectCategories/003.backpack/003_0123.jpg
# 256_ObjectCategories/003.backpack/003_0124.jpg
# 256_ObjectCategories/003.backpack/003_0125.jpg
# 256_ObjectCategories/003.backpack/003_0126.jpg
# 256_ObjectCategories/003.backpack/003_0127.jpg
# 256_ObjectCategories/003.backpack/003_0128.jpg
# 256_ObjectCategories/003.backpack/003_0129.jpg
# 256_ObjectCategories/003.backpack/003_0130.jpg
# 256_ObjectCategories/003.backpack/003_0131.jpg
# 256_ObjectCategories/003.backpack/003_0132.jpg
# 256_ObjectCategories/003.backpack/003_0133.jpg
# 256_ObjectCategories/003.backpack/003_0134.jpg
# 256_ObjectCategories/003.backpack/003_0135.jpg
# 256_ObjectCategories/003.backpack/003_0136.jpg
# 256_ObjectCategories/003.backpack/003_0137.jpg
# 256_ObjectCategories/003.backpack/003_0138.jpg
# 256_ObjectCategories/003.backpack/003_0139.jpg
# 256_ObjectCategories/003.backpack/003_0140.jpg
# 256_ObjectCategories/003.backpack/003_0141.jpg
# 256_ObjectCategories/003.backpack/003_0142.jpg
# 256_ObjectCategories/003.backpack/003_0143.jpg
# 256_ObjectCategories/003.backpack/003_0144.jpg
# 256_ObjectCategories/003.backpack/003_0145.jpg
# 256_ObjectCategories/003.backpack/003_0146.jpg
# 256_ObjectCategories/003.backpack/003_0147.jpg
# 256_ObjectCategories/003.backpack/003_0148.jpg
# 256_ObjectCategories/003.backpack/003_0149.jpg
# 256_ObjectCategories/003.backpack/003_0150.jpg
# 256_ObjectCategories/003.backpack/003_0151.jpg
# 256_ObjectCategories/004.baseball-bat/
# 256_ObjectCategories/004.baseball-bat/004_0001.jpg
# 256_ObjectCategories/004.baseball-bat/004_0002.jpg
# 256_ObjectCategories/004.baseball-bat/004_0003.jpg
# 256_ObjectCategories/004.baseball-bat/004_0004.jpg
# 256_ObjectCategories/004.baseball-bat/004_0005.jpg
# 256_ObjectCategories/004.baseball-bat/004_0006.jpg
# 256_ObjectCategories/004.baseball-bat/004_0007.jpg
# 256_ObjectCategories/004.baseball-bat/004_0008.jpg
# 256_ObjectCategories/004.baseball-bat/004_0009.jpg
# 256_ObjectCategories/004.baseball-bat/004_0010.jpg
# 256_ObjectCategories/004.baseball-bat/004_0011.jpg
# 256_ObjectCategories/004.baseball-bat/004_0012.jpg
# 256_ObjectCategories/004.baseball-bat/004_0013.jpg
# 256_ObjectCategories/004.baseball-bat/004_0014.jpg
# 256_ObjectCategories/004.baseball-bat/004_0015.jpg
# 256_ObjectCategories/004.baseball-bat/004_0016.jpg
# 256_ObjectCategories/004.baseball-bat/004_0017.jpg
# 256_ObjectCategories/004.baseball-bat/004_0018.jpg
# 256_ObjectCategories/004.baseball-bat/004_0019.jpg
# 256_ObjectCategories/004.baseball-bat/004_0020.jpg
# 256_ObjectCategories/004.baseball-bat/004_0021.jpg
# 256_ObjectCategories/004.baseball-bat/004_0022.jpg
# 256_ObjectCategories/004.baseball-bat/004_0023.jpg
# 256_ObjectCategories/004.baseball-bat/004_0024.jpg
# 256_ObjectCategories/004.baseball-bat/004_0025.jpg
# 256_ObjectCategories/004.baseball-bat/004_0026.jpg
# 256_ObjectCategories/004.baseball-bat/004_0027.jpg
# 256_ObjectCategories/004.baseball-bat/004_0028.jpg
# 256_ObjectCategories/004.baseball-bat/004_0029.jpg
# 256_ObjectCategories/004.baseball-bat/004_0030.jpg
# 256_ObjectCategories/004.baseball-bat/004_0031.jpg
# 256_ObjectCategories/004.baseball-bat/004_0032.jpg
# 256_ObjectCategories/004.baseball-bat/004_0033.jpg
# 256_ObjectCategories/004.baseball-bat/004_0034.jpg
# 256_ObjectCategories/004.baseball-bat/004_0035.jpg
# 256_ObjectCategories/004.baseball-bat/004_0036.jpg
# 256_ObjectCategories/004.baseball-bat/004_0037.jpg
# 256_ObjectCategories/004.baseball-bat/004_0038.jpg
# 256_ObjectCategories/004.baseball-bat/004_0039.jpg
# 256_ObjectCategories/004.baseball-bat/004_0040.jpg
# 256_ObjectCategories/004.baseball-bat/004_0041.jpg
# 256_ObjectCategories/004.baseball-bat/004_0042.jpg
# 256_ObjectCategories/004.baseball-bat/004_0043.jpg
# 256_ObjectCategories/004.baseball-bat/004_0044.jpg
# 256_ObjectCategories/004.baseball-bat/004_0045.jpg
# 256_ObjectCategories/004.baseball-bat/004_0046.jpg
# 256_ObjectCategories/004.baseball-bat/004_0047.jpg
# 256_ObjectCategories/004.baseball-bat/004_0048.jpg
# 256_ObjectCategories/004.baseball-bat/004_0049.jpg
# 256_ObjectCategories/004.baseball-bat/004_0050.jpg
# 256_ObjectCategories/004.baseball-bat/004_0051.jpg
# 256_ObjectCategories/004.baseball-bat/004_0052.jpg
# 256_ObjectCategories/004.baseball-bat/004_0053.jpg
# 256_ObjectCategories/004.baseball-bat/004_0054.jpg
# 256_ObjectCategories/004.baseball-bat/004_0055.jpg
# 256_ObjectCategories/004.baseball-bat/004_0056.jpg
# 256_ObjectCategories/004.baseball-bat/004_0057.jpg
# 256_ObjectCategories/004.baseball-bat/004_0058.jpg
# 256_ObjectCategories/004.baseball-bat/004_0059.jpg
# 256_ObjectCategories/004.baseball-bat/004_0060.jpg
# 256_ObjectCategories/004.baseball-bat/004_0061.jpg
# 256_ObjectCategories/004.baseball-bat/004_0062.jpg
# 256_ObjectCategories/004.baseball-bat/004_0063.jpg
# 256_ObjectCategories/004.baseball-bat/004_0064.jpg
# 256_ObjectCategories/004.baseball-bat/004_0065.jpg
# 256_ObjectCategories/004.baseball-bat/004_0066.jpg
# 256_ObjectCategories/004.baseball-bat/004_0067.jpg
# 256_ObjectCategories/004.baseball-bat/004_0068.jpg
# 256_ObjectCategories/004.baseball-bat/004_0069.jpg
# 256_ObjectCategories/004.baseball-bat/004_0070.jpg
# 256_ObjectCategories/004.baseball-bat/004_0071.jpg
# 256_ObjectCategories/004.baseball-bat/004_0072.jpg
# 256_ObjectCategories/004.baseball-bat/004_0073.jpg
# 256_ObjectCategories/004.baseball-bat/004_0074.jpg
# 256_ObjectCategories/004.baseball-bat/004_0075.jpg
# 256_ObjectCategories/004.baseball-bat/004_0076.jpg
# 256_ObjectCategories/004.baseball-bat/004_0077.jpg
# 256_ObjectCategories/004.baseball-bat/004_0078.jpg
# 256_ObjectCategories/004.baseball-bat/004_0079.jpg
# 256_ObjectCategories/004.baseball-bat/004_0080.jpg
# 256_ObjectCategories/004.baseball-bat/004_0081.jpg
# 256_ObjectCategories/004.baseball-bat/004_0082.jpg
# 256_ObjectCategories/004.baseball-bat/004_0083.jpg
# 256_ObjectCategories/004.baseball-bat/004_0084.jpg
# 256_ObjectCategories/004.baseball-bat/004_0085.jpg
# 256_ObjectCategories/004.baseball-bat/004_0086.jpg
# 256_ObjectCategories/004.baseball-bat/004_0087.jpg
# 256_ObjectCategories/004.baseball-bat/004_0088.jpg
# 256_ObjectCategories/004.baseball-bat/004_0089.jpg
# 256_ObjectCategories/004.baseball-bat/004_0090.jpg
# 256_ObjectCategories/004.baseball-bat/004_0091.jpg
# 256_ObjectCategories/004.baseball-bat/004_0092.jpg
# 256_ObjectCategories/004.baseball-bat/004_0093.jpg
# 256_ObjectCategories/004.baseball-bat/004_0094.jpg
# 256_ObjectCategories/004.baseball-bat/004_0095.jpg
# 256_ObjectCategories/004.baseball-bat/004_0096.jpg
# 256_ObjectCategories/004.baseball-bat/004_0097.jpg
# 256_ObjectCategories/004.baseball-bat/004_0098.jpg
# 256_ObjectCategories/004.baseball-bat/004_0099.jpg
# 256_ObjectCategories/004.baseball-bat/004_0100.jpg
# 256_ObjectCategories/004.baseball-bat/004_0101.jpg
# 256_ObjectCategories/004.baseball-bat/004_0102.jpg
# 256_ObjectCategories/004.baseball-bat/004_0103.jpg
# 256_ObjectCategories/004.baseball-bat/004_0104.jpg
# 256_ObjectCategories/004.baseball-bat/004_0105.jpg
# 256_ObjectCategories/004.baseball-bat/004_0106.jpg
# 256_ObjectCategories/004.baseball-bat/004_0107.jpg
# 256_ObjectCategories/004.baseball-bat/004_0108.jpg
# 256_ObjectCategories/004.baseball-bat/004_0109.jpg
# 256_ObjectCategories/004.baseball-bat/004_0110.jpg
# 256_ObjectCategories/004.baseball-bat/004_0111.jpg
# 256_ObjectCategories/004.baseball-bat/004_0112.jpg
# 256_ObjectCategories/004.baseball-bat/004_0113.jpg
# 256_ObjectCategories/004.baseball-bat/004_0114.jpg
# 256_ObjectCategories/004.baseball-bat/004_0115.jpg
# 256_ObjectCategories/004.baseball-bat/004_0116.jpg
# 256_ObjectCategories/004.baseball-bat/004_0117.jpg
# 256_ObjectCategories/004.baseball-bat/004_0118.jpg
# 256_ObjectCategories/004.baseball-bat/004_0119.jpg
# 256_ObjectCategories/004.baseball-bat/004_0120.jpg
# 256_ObjectCategories/004.baseball-bat/004_0121.jpg
# 256_ObjectCategories/004.baseball-bat/004_0122.jpg
# 256_ObjectCategories/004.baseball-bat/004_0123.jpg
# 256_ObjectCategories/004.baseball-bat/004_0124.jpg
# 256_ObjectCategories/004.baseball-bat/004_0125.jpg
# 256_ObjectCategories/004.baseball-bat/004_0126.jpg
# 256_ObjectCategories/004.baseball-bat/004_0127.jpg
# 256_ObjectCategories/005.baseball-glove/
# 256_ObjectCategories/005.baseball-glove/005_0001.jpg
# 256_ObjectCategories/005.baseball-glove/005_0002.jpg
# 256_ObjectCategories/005.baseball-glove/005_0003.jpg
# 256_ObjectCategories/005.baseball-glove/005_0004.jpg
# 256_ObjectCategories/005.baseball-glove/005_0005.jpg
# 256_ObjectCategories/005.baseball-glove/005_0006.jpg
# 256_ObjectCategories/005.baseball-glove/005_0007.jpg
# 256_ObjectCategories/005.baseball-glove/005_0008.jpg
# 256_ObjectCategories/005.baseball-glove/005_0009.jpg
# 256_ObjectCategories/005.baseball-glove/005_0010.jpg
# 256_ObjectCategories/005.baseball-glove/005_0011.jpg
# 256_ObjectCategories/005.baseball-glove/005_0012.jpg
# 256_ObjectCategories/005.baseball-glove/005_0013.jpg
# 256_ObjectCategories/005.baseball-glove/005_0014.jpg
# 256_ObjectCategories/005.baseball-glove/005_0015.jpg
# 256_ObjectCategories/005.baseball-glove/005_0016.jpg
# 256_ObjectCategories/005.baseball-glove/005_0017.jpg
# 256_ObjectCategories/005.baseball-glove/005_0018.jpg
# 256_ObjectCategories/005.baseball-glove/005_0019.jpg
# 256_ObjectCategories/005.baseball-glove/005_0020.jpg
# 256_ObjectCategories/005.baseball-glove/005_0021.jpg
# 256_ObjectCategories/005.baseball-glove/005_0022.jpg
# 256_ObjectCategories/005.baseball-glove/005_0023.jpg
# 256_ObjectCategories/005.baseball-glove/005_0024.jpg
# 256_ObjectCategories/005.baseball-glove/005_0025.jpg
# 256_ObjectCategories/005.baseball-glove/005_0026.jpg
# 256_ObjectCategories/005.baseball-glove/005_0027.jpg
# 256_ObjectCategories/005.baseball-glove/005_0028.jpg
# 256_ObjectCategories/005.baseball-glove/005_0029.jpg
# 256_ObjectCategories/005.baseball-glove/005_0030.jpg
# 256_ObjectCategories/005.baseball-glove/005_0031.jpg
# 256_ObjectCategories/005.baseball-glove/005_0032.jpg
# 256_ObjectCategories/005.baseball-glove/005_0033.jpg
# 256_ObjectCategories/005.baseball-glove/005_0034.jpg
# 256_ObjectCategories/005.baseball-glove/005_0035.jpg
# 256_ObjectCategories/005.baseball-glove/005_0036.jpg
# 256_ObjectCategories/005.baseball-glove/005_0037.jpg
# 256_ObjectCategories/005.baseball-glove/005_0038.jpg
# 256_ObjectCategories/005.baseball-glove/005_0039.jpg
# 256_ObjectCategories/005.baseball-glove/005_0040.jpg
# 256_ObjectCategories/005.baseball-glove/005_0041.jpg
# 256_ObjectCategories/005.baseball-glove/005_0042.jpg
# 256_ObjectCategories/005.baseball-glove/005_0043.jpg
# 256_ObjectCategories/005.baseball-glove/005_0044.jpg
# 256_ObjectCategories/005.baseball-glove/005_0045.jpg
# 256_ObjectCategories/005.baseball-glove/005_0046.jpg
# 256_ObjectCategories/005.baseball-glove/005_0047.jpg
# 256_ObjectCategories/005.baseball-glove/005_0048.jpg
# 256_ObjectCategories/005.baseball-glove/005_0049.jpg
# 256_ObjectCategories/005.baseball-glove/005_0050.jpg
# 256_ObjectCategories/005.baseball-glove/005_0051.jpg
# 256_ObjectCategories/005.baseball-glove/005_0052.jpg
# 256_ObjectCategories/005.baseball-glove/005_0053.jpg
# 256_ObjectCategories/005.baseball-glove/005_0054.jpg
# 256_ObjectCategories/005.baseball-glove/005_0055.jpg
# 256_ObjectCategories/005.baseball-glove/005_0056.jpg
# 256_ObjectCategories/005.baseball-glove/005_0057.jpg
# 256_ObjectCategories/005.baseball-glove/005_0058.jpg
# 256_ObjectCategories/005.baseball-glove/005_0059.jpg
# 256_ObjectCategories/005.baseball-glove/005_0060.jpg
# 256_ObjectCategories/005.baseball-glove/005_0061.jpg
# 256_ObjectCategories/005.baseball-glove/005_0062.jpg
# 256_ObjectCategories/005.baseball-glove/005_0063.jpg
# 256_ObjectCategories/005.baseball-glove/005_0064.jpg
# 256_ObjectCategories/005.baseball-glove/005_0065.jpg
# 256_ObjectCategories/005.baseball-glove/005_0066.jpg
# 256_ObjectCategories/005.baseball-glove/005_0067.jpg
# 256_ObjectCategories/005.baseball-glove/005_0068.jpg
# 256_ObjectCategories/005.baseball-glove/005_0069.jpg
# 256_ObjectCategories/005.baseball-glove/005_0070.jpg
# 256_ObjectCategories/005.baseball-glove/005_0071.jpg
# 256_ObjectCategories/005.baseball-glove/005_0072.jpg
# 256_ObjectCategories/005.baseball-glove/005_0073.jpg
# 256_ObjectCategories/005.baseball-glove/005_0074.jpg
# 256_ObjectCategories/005.baseball-glove/005_0075.jpg
# 256_ObjectCategories/005.baseball-glove/005_0076.jpg
# 256_ObjectCategories/005.baseball-glove/005_0077.jpg
# 256_ObjectCategories/005.baseball-glove/005_0078.jpg
# 256_ObjectCategories/005.baseball-glove/005_0079.jpg
# 256_ObjectCategories/005.baseball-glove/005_0080.jpg
# 256_ObjectCategories/005.baseball-glove/005_0081.jpg
# 256_ObjectCategories/005.baseball-glove/005_0082.jpg
# 256_ObjectCategories/005.baseball-glove/005_0083.jpg
# 256_ObjectCategories/005.baseball-glove/005_0084.jpg
# 256_ObjectCategories/005.baseball-glove/005_0085.jpg
# 256_ObjectCategories/005.baseball-glove/005_0086.jpg
# 256_ObjectCategories/005.baseball-glove/005_0087.jpg
# 256_ObjectCategories/005.baseball-glove/005_0088.jpg
# 256_ObjectCategories/005.baseball-glove/005_0089.jpg
# 256_ObjectCategories/005.baseball-glove/005_0090.jpg
# 256_ObjectCategories/005.baseball-glove/005_0091.jpg
# 256_ObjectCategories/005.baseball-glove/005_0092.jpg
# 256_ObjectCategories/005.baseball-glove/005_0093.jpg
# 256_ObjectCategories/005.baseball-glove/005_0094.jpg
# 256_ObjectCategories/005.baseball-glove/005_0095.jpg
# 256_ObjectCategories/005.baseball-glove/005_0096.jpg
# 256_ObjectCategories/005.baseball-glove/005_0097.jpg
# 256_ObjectCategories/005.baseball-glove/005_0098.jpg
# 256_ObjectCategories/005.baseball-glove/005_0099.jpg
# 256_ObjectCategories/005.baseball-glove/005_0100.jpg
# 256_ObjectCategories/005.baseball-glove/005_0101.jpg
# 256_ObjectCategories/005.baseball-glove/005_0102.jpg
# 256_ObjectCategories/005.baseball-glove/005_0103.jpg
# 256_ObjectCategories/005.baseball-glove/005_0104.jpg
# 256_ObjectCategories/005.baseball-glove/005_0105.jpg
# 256_ObjectCategories/005.baseball-glove/005_0106.jpg
# 256_ObjectCategories/005.baseball-glove/005_0107.jpg
# 256_ObjectCategories/005.baseball-glove/005_0108.jpg
# 256_ObjectCategories/005.baseball-glove/005_0109.jpg
# 256_ObjectCategories/005.baseball-glove/005_0110.jpg
# 256_ObjectCategories/005.baseball-glove/005_0111.jpg
# 256_ObjectCategories/005.baseball-glove/005_0112.jpg
# 256_ObjectCategories/005.baseball-glove/005_0113.jpg
# 256_ObjectCategories/005.baseball-glove/005_0114.jpg
# 256_ObjectCategories/005.baseball-glove/005_0115.jpg
# 256_ObjectCategories/005.baseball-glove/005_0116.jpg
# 256_ObjectCategories/005.baseball-glove/005_0117.jpg
# 256_ObjectCategories/005.baseball-glove/005_0118.jpg
# 256_ObjectCategories/005.baseball-glove/005_0119.jpg
# 256_ObjectCategories/005.baseball-glove/005_0120.jpg
# 256_ObjectCategories/005.baseball-glove/005_0121.jpg
# 256_ObjectCategories/005.baseball-glove/005_0122.jpg
# 256_ObjectCategories/005.baseball-glove/005_0123.jpg
# 256_ObjectCategories/005.baseball-glove/005_0124.jpg
# 256_ObjectCategories/005.baseball-glove/005_0125.jpg
# 256_ObjectCategories/005.baseball-glove/005_0126.jpg
# 256_ObjectCategories/005.baseball-glove/005_0127.jpg
# 256_ObjectCategories/005.baseball-glove/005_0128.jpg
# 256_ObjectCategories/005.baseball-glove/005_0129.jpg
# 256_ObjectCategories/005.baseball-glove/005_0130.jpg
# 256_ObjectCategories/005.baseball-glove/005_0131.jpg
# 256_ObjectCategories/005.baseball-glove/005_0132.jpg
# 256_ObjectCategories/005.baseball-glove/005_0133.jpg
# 256_ObjectCategories/005.baseball-glove/005_0134.jpg
# 256_ObjectCategories/005.baseball-glove/005_0135.jpg
# 256_ObjectCategories/005.baseball-glove/005_0136.jpg
# 256_ObjectCategories/005.baseball-glove/005_0137.jpg
# 256_ObjectCategories/005.baseball-glove/005_0138.jpg
# 256_ObjectCategories/005.baseball-glove/005_0139.jpg
# 256_ObjectCategories/005.baseball-glove/005_0140.jpg
# 256_ObjectCategories/005.baseball-glove/005_0141.jpg
# 256_ObjectCategories/005.baseball-glove/005_0142.jpg
# 256_ObjectCategories/005.baseball-glove/005_0143.jpg
# 256_ObjectCategories/005.baseball-glove/005_0144.jpg
# 256_ObjectCategories/005.baseball-glove/005_0145.jpg
# 256_ObjectCategories/005.baseball-glove/005_0146.jpg
# 256_ObjectCategories/005.baseball-glove/005_0147.jpg
# 256_ObjectCategories/005.baseball-glove/005_0148.jpg
# 256_ObjectCategories/006.basketball-hoop/
# 256_ObjectCategories/006.basketball-hoop/006_0001.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0002.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0003.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0004.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0005.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0006.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0007.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0008.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0009.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0010.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0011.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0012.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0013.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0014.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0015.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0016.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0017.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0018.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0019.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0020.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0021.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0022.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0023.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0024.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0025.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0026.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0027.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0028.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0029.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0030.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0031.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0032.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0033.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0034.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0035.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0036.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0037.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0038.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0039.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0040.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0041.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0042.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0043.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0044.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0045.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0046.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0047.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0048.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0049.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0050.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0051.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0052.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0053.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0054.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0055.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0056.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0057.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0058.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0059.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0060.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0061.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0062.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0063.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0064.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0065.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0066.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0067.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0068.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0069.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0070.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0071.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0072.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0073.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0074.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0075.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0076.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0077.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0078.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0079.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0080.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0081.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0082.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0083.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0084.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0085.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0086.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0087.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0088.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0089.jpg
# 256_ObjectCategories/006.basketball-hoop/006_0090.jpg
# 256_ObjectCategories/007.bat/
# 256_ObjectCategories/007.bat/007_0001.jpg
# 256_ObjectCategories/007.bat/007_0002.jpg
# 256_ObjectCategories/007.bat/007_0003.jpg
# 256_ObjectCategories/007.bat/007_0004.jpg
# 256_ObjectCategories/007.bat/007_0005.jpg
# 256_ObjectCategories/007.bat/007_0006.jpg
# 256_ObjectCategories/007.bat/007_0007.jpg
# 256_ObjectCategories/007.bat/007_0008.jpg
# 256_ObjectCategories/007.bat/007_0009.jpg
# 256_ObjectCategories/007.bat/007_0010.jpg
# 256_ObjectCategories/007.bat/007_0011.jpg
# 256_ObjectCategories/007.bat/007_0012.jpg
# 256_ObjectCategories/007.bat/007_0013.jpg
# 256_ObjectCategories/007.bat/007_0014.jpg
# 256_ObjectCategories/007.bat/007_0015.jpg
# 256_ObjectCategories/007.bat/007_0016.jpg
# 256_ObjectCategories/007.bat/007_0017.jpg
# 256_ObjectCategories/007.bat/007_0018.jpg
# 256_ObjectCategories/007.bat/007_0019.jpg
# 256_ObjectCategories/007.bat/007_0020.jpg
# 256_ObjectCategories/007.bat/007_0021.jpg
# 256_ObjectCategories/007.bat/007_0022.jpg
# 256_ObjectCategories/007.bat/007_0023.jpg
# 256_ObjectCategories/007.bat/007_0024.jpg
# 256_ObjectCategories/007.bat/007_0025.jpg
# 256_ObjectCategories/007.bat/007_0026.jpg
# 256_ObjectCategories/007.bat/007_0027.jpg
# 256_ObjectCategories/007.bat/007_0028.jpg
# 256_ObjectCategories/007.bat/007_0029.jpg
# 256_ObjectCategories/007.bat/007_0030.jpg
# 256_ObjectCategories/007.bat/007_0031.jpg
# 256_ObjectCategories/007.bat/007_0032.jpg
# 256_ObjectCategories/007.bat/007_0033.jpg
# 256_ObjectCategories/007.bat/007_0034.jpg
# 256_ObjectCategories/007.bat/007_0035.jpg
# 256_ObjectCategories/007.bat/007_0036.jpg
# 256_ObjectCategories/007.bat/007_0037.jpg
# 256_ObjectCategories/007.bat/007_0038.jpg
# 256_ObjectCategories/007.bat/007_0039.jpg
# 256_ObjectCategories/007.bat/007_0040.jpg
# 256_ObjectCategories/007.bat/007_0041.jpg
# 256_ObjectCategories/007.bat/007_0042.jpg
# 256_ObjectCategories/007.bat/007_0043.jpg
# 256_ObjectCategories/007.bat/007_0044.jpg
# 256_ObjectCategories/007.bat/007_0045.jpg
# 256_ObjectCategories/007.bat/007_0046.jpg
# 256_ObjectCategories/007.bat/007_0047.jpg
# 256_ObjectCategories/007.bat/007_0048.jpg
# 256_ObjectCategories/007.bat/007_0049.jpg
# 256_ObjectCategories/007.bat/007_0050.jpg
# 256_ObjectCategories/007.bat/007_0051.jpg
# 256_ObjectCategories/007.bat/007_0052.jpg
# 256_ObjectCategories/007.bat/007_0053.jpg
# 256_ObjectCategories/007.bat/007_0054.jpg
# 256_ObjectCategories/007.bat/007_0055.jpg
# 256_ObjectCategories/007.bat/007_0056.jpg
# 256_ObjectCategories/007.bat/007_0057.jpg
# 256_ObjectCategories/007.bat/007_0058.jpg
# 256_ObjectCategories/007.bat/007_0059.jpg
# 256_ObjectCategories/007.bat/007_0060.jpg
# 256_ObjectCategories/007.bat/007_0061.jpg
# 256_ObjectCategories/007.bat/007_0062.jpg
# 256_ObjectCategories/007.bat/007_0063.jpg
# 256_ObjectCategories/007.bat/007_0064.jpg
# 256_ObjectCategories/007.bat/007_0065.jpg
# 256_ObjectCategories/007.bat/007_0066.jpg
# 256_ObjectCategories/007.bat/007_0067.jpg
# 256_ObjectCategories/007.bat/007_0068.jpg
# 256_ObjectCategories/007.bat/007_0069.jpg
# 256_ObjectCategories/007.bat/007_0070.jpg
# 256_ObjectCategories/007.bat/007_0071.jpg
# 256_ObjectCategories/007.bat/007_0072.jpg
# 256_ObjectCategories/007.bat/007_0073.jpg
# 256_ObjectCategories/007.bat/007_0074.jpg
# 256_ObjectCategories/007.bat/007_0075.jpg
# 256_ObjectCategories/007.bat/007_0076.jpg
# 256_ObjectCategories/007.bat/007_0077.jpg
# 256_ObjectCategories/007.bat/007_0078.jpg
# 256_ObjectCategories/007.bat/007_0079.jpg
# 256_ObjectCategories/007.bat/007_0080.jpg
# 256_ObjectCategories/007.bat/007_0081.jpg
# 256_ObjectCategories/007.bat/007_0082.jpg
# 256_ObjectCategories/007.bat/007_0083.jpg
# 256_ObjectCategories/007.bat/007_0084.jpg
# 256_ObjectCategories/007.bat/007_0085.jpg
# 256_ObjectCategories/007.bat/007_0086.jpg
# 256_ObjectCategories/007.bat/007_0087.jpg
# 256_ObjectCategories/007.bat/007_0088.jpg
# 256_ObjectCategories/007.bat/007_0089.jpg
# 256_ObjectCategories/007.bat/007_0090.jpg
# 256_ObjectCategories/007.bat/007_0091.jpg
# 256_ObjectCategories/007.bat/007_0092.jpg
# 256_ObjectCategories/007.bat/007_0093.jpg
# 256_ObjectCategories/007.bat/007_0094.jpg
# 256_ObjectCategories/007.bat/007_0095.jpg
# 256_ObjectCategories/007.bat/007_0096.jpg
# 256_ObjectCategories/007.bat/007_0097.jpg
# 256_ObjectCategories/007.bat/007_0098.jpg
# 256_ObjectCategories/007.bat/007_0099.jpg
# 256_ObjectCategories/007.bat/007_0100.jpg
# 256_ObjectCategories/007.bat/007_0101.jpg
# 256_ObjectCategories/007.bat/007_0102.jpg
# 256_ObjectCategories/007.bat/007_0103.jpg
# 256_ObjectCategories/007.bat/007_0104.jpg
# 256_ObjectCategories/007.bat/007_0105.jpg
# 256_ObjectCategories/007.bat/007_0106.jpg
# 256_ObjectCategories/008.bathtub/
# 256_ObjectCategories/008.bathtub/008_0001.jpg
# 256_ObjectCategories/008.bathtub/008_0002.jpg
# 256_ObjectCategories/008.bathtub/008_0003.jpg
# 256_ObjectCategories/008.bathtub/008_0004.jpg
# 256_ObjectCategories/008.bathtub/008_0005.jpg
# 256_ObjectCategories/008.bathtub/008_0006.jpg
# 256_ObjectCategories/008.bathtub/008_0007.jpg
# 256_ObjectCategories/008.bathtub/008_0008.jpg
# 256_ObjectCategories/008.bathtub/008_0009.jpg
# 256_ObjectCategories/008.bathtub/008_0010.jpg
# 256_ObjectCategories/008.bathtub/008_0011.jpg
# 256_ObjectCategories/008.bathtub/008_0012.jpg
# 256_ObjectCategories/008.bathtub/008_0013.jpg
# 256_ObjectCategories/008.bathtub/008_0014.jpg
# 256_ObjectCategories/008.bathtub/008_0015.jpg
# 256_ObjectCategories/008.bathtub/008_0016.jpg
# 256_ObjectCategories/008.bathtub/008_0017.jpg
# 256_ObjectCategories/008.bathtub/008_0018.jpg
# 256_ObjectCategories/008.bathtub/008_0019.jpg
# 256_ObjectCategories/008.bathtub/008_0020.jpg
# 256_ObjectCategories/008.bathtub/008_0021.jpg
# 256_ObjectCategories/008.bathtub/008_0022.jpg
# 256_ObjectCategories/008.bathtub/008_0023.jpg
# 256_ObjectCategories/008.bathtub/008_0024.jpg
# 256_ObjectCategories/008.bathtub/008_0025.jpg
# 256_ObjectCategories/008.bathtub/008_0026.jpg
# 256_ObjectCategories/008.bathtub/008_0027.jpg
# 256_ObjectCategories/008.bathtub/008_0028.jpg
# 256_ObjectCategories/008.bathtub/008_0029.jpg
# 256_ObjectCategories/008.bathtub/008_0030.jpg
# 256_ObjectCategories/008.bathtub/008_0031.jpg
# 256_ObjectCategories/008.bathtub/008_0032.jpg
# 256_ObjectCategories/008.bathtub/008_0033.jpg
# 256_ObjectCategories/008.bathtub/008_0034.jpg
# 256_ObjectCategories/008.bathtub/008_0035.jpg
# 256_ObjectCategories/008.bathtub/008_0036.jpg
# 256_ObjectCategories/008.bathtub/008_0037.jpg
# 256_ObjectCategories/008.bathtub/008_0038.jpg
# 256_ObjectCategories/008.bathtub/008_0039.jpg
# 256_ObjectCategories/008.bathtub/008_0040.jpg
# 256_ObjectCategories/008.bathtub/008_0041.jpg
# 256_ObjectCategories/008.bathtub/008_0042.jpg
# 256_ObjectCategories/008.bathtub/008_0043.jpg
# 256_ObjectCategories/008.bathtub/008_0044.jpg
# 256_ObjectCategories/008.bathtub/008_0045.jpg
# 256_ObjectCategories/008.bathtub/008_0046.jpg
# 256_ObjectCategories/008.bathtub/008_0047.jpg
# 256_ObjectCategories/008.bathtub/008_0048.jpg
# 256_ObjectCategories/008.bathtub/008_0049.jpg
# 256_ObjectCategories/008.bathtub/008_0050.jpg
# 256_ObjectCategories/008.bathtub/008_0051.jpg
# 256_ObjectCategories/008.bathtub/008_0052.jpg
# 256_ObjectCategories/008.bathtub/008_0053.jpg
# 256_ObjectCategories/008.bathtub/008_0054.jpg
# 256_ObjectCategories/008.bathtub/008_0055.jpg
# 256_ObjectCategories/008.bathtub/008_0056.jpg
# 256_ObjectCategories/008.bathtub/008_0057.jpg
# 256_ObjectCategories/008.bathtub/008_0058.jpg
# 256_ObjectCategories/008.bathtub/008_0059.jpg
# 256_ObjectCategories/008.bathtub/008_0060.jpg
# 256_ObjectCategories/008.bathtub/008_0061.jpg
# 256_ObjectCategories/008.bathtub/008_0062.jpg
# 256_ObjectCategories/008.bathtub/008_0063.jpg
# 256_ObjectCategories/008.bathtub/008_0064.jpg
# 256_ObjectCategories/008.bathtub/008_0065.jpg
# 256_ObjectCategories/008.bathtub/008_0066.jpg
# 256_ObjectCategories/008.bathtub/008_0067.jpg
# 256_ObjectCategories/008.bathtub/008_0068.jpg
# 256_ObjectCategories/008.bathtub/008_0069.jpg
# 256_ObjectCategories/008.bathtub/008_0070.jpg
# 256_ObjectCategories/008.bathtub/008_0071.jpg
# 256_ObjectCategories/008.bathtub/008_0072.jpg
# 256_ObjectCategories/008.bathtub/008_0073.jpg
# 256_ObjectCategories/008.bathtub/008_0074.jpg
# 256_ObjectCategories/008.bathtub/008_0075.jpg
# 256_ObjectCategories/008.bathtub/008_0076.jpg
# 256_ObjectCategories/008.bathtub/008_0077.jpg
# 256_ObjectCategories/008.bathtub/008_0078.jpg
# 256_ObjectCategories/008.bathtub/008_0079.jpg
# 256_ObjectCategories/008.bathtub/008_0080.jpg
# 256_ObjectCategories/008.bathtub/008_0081.jpg
# 256_ObjectCategories/008.bathtub/008_0082.jpg
# 256_ObjectCategories/008.bathtub/008_0083.jpg
# 256_ObjectCategories/008.bathtub/008_0084.jpg
# 256_ObjectCategories/008.bathtub/008_0085.jpg
# 256_ObjectCategories/008.bathtub/008_0086.jpg
# 256_ObjectCategories/008.bathtub/008_0087.jpg
# 256_ObjectCategories/008.bathtub/008_0088.jpg
# 256_ObjectCategories/008.bathtub/008_0089.jpg
# 256_ObjectCategories/008.bathtub/008_0090.jpg
# 256_ObjectCategories/008.bathtub/008_0091.jpg
# 256_ObjectCategories/008.bathtub/008_0092.jpg
# 256_ObjectCategories/008.bathtub/008_0093.jpg
# 256_ObjectCategories/008.bathtub/008_0094.jpg
# 256_ObjectCategories/008.bathtub/008_0095.jpg
# 256_ObjectCategories/008.bathtub/008_0096.jpg
# 256_ObjectCategories/008.bathtub/008_0097.jpg
# 256_ObjectCategories/008.bathtub/008_0098.jpg
# 256_ObjectCategories/008.bathtub/008_0099.jpg
# 256_ObjectCategories/008.bathtub/008_0100.jpg
# 256_ObjectCategories/008.bathtub/008_0101.jpg
# 256_ObjectCategories/008.bathtub/008_0102.jpg
# 256_ObjectCategories/008.bathtub/008_0103.jpg
# 256_ObjectCategories/008.bathtub/008_0104.jpg
# 256_ObjectCategories/008.bathtub/008_0105.jpg
# 256_ObjectCategories/008.bathtub/008_0106.jpg
# 256_ObjectCategories/008.bathtub/008_0107.jpg
# 256_ObjectCategories/008.bathtub/008_0108.jpg
# 256_ObjectCategories/008.bathtub/008_0109.jpg
# 256_ObjectCategories/008.bathtub/008_0110.jpg
# 256_ObjectCategories/008.bathtub/008_0111.jpg
# 256_ObjectCategories/008.bathtub/008_0112.jpg
# 256_ObjectCategories/008.bathtub/008_0113.jpg
# 256_ObjectCategories/008.bathtub/008_0114.jpg
# 256_ObjectCategories/008.bathtub/008_0115.jpg
# 256_ObjectCategories/008.bathtub/008_0116.jpg
# 256_ObjectCategories/008.bathtub/008_0117.jpg
# 256_ObjectCategories/008.bathtub/008_0118.jpg
# 256_ObjectCategories/008.bathtub/008_0119.jpg
# 256_ObjectCategories/008.bathtub/008_0120.jpg
# 256_ObjectCategories/008.bathtub/008_0121.jpg
# 256_ObjectCategories/008.bathtub/008_0122.jpg
# 256_ObjectCategories/008.bathtub/008_0123.jpg
# 256_ObjectCategories/008.bathtub/008_0124.jpg
# 256_ObjectCategories/008.bathtub/008_0125.jpg
# 256_ObjectCategories/008.bathtub/008_0126.jpg
# 256_ObjectCategories/008.bathtub/008_0127.jpg
# 256_ObjectCategories/008.bathtub/008_0128.jpg
# 256_ObjectCategories/008.bathtub/008_0129.jpg
# 256_ObjectCategories/008.bathtub/008_0130.jpg
# 256_ObjectCategories/008.bathtub/008_0131.jpg
# 256_ObjectCategories/008.bathtub/008_0132.jpg
# 256_ObjectCategories/008.bathtub/008_0133.jpg
# 256_ObjectCategories/008.bathtub/008_0134.jpg
# 256_ObjectCategories/008.bathtub/008_0135.jpg
# 256_ObjectCategories/008.bathtub/008_0136.jpg
# 256_ObjectCategories/008.bathtub/008_0137.jpg
# 256_ObjectCategories/008.bathtub/008_0138.jpg
# 256_ObjectCategories/008.bathtub/008_0139.jpg
# 256_ObjectCategories/008.bathtub/008_0140.jpg
# 256_ObjectCategories/008.bathtub/008_0141.jpg
# 256_ObjectCategories/008.bathtub/008_0142.jpg
# 256_ObjectCategories/008.bathtub/008_0143.jpg
# 256_ObjectCategories/008.bathtub/008_0144.jpg
# 256_ObjectCategories/008.bathtub/008_0145.jpg
# 256_ObjectCategories/008.bathtub/008_0146.jpg
# 256_ObjectCategories/008.bathtub/008_0147.jpg
# 256_ObjectCategories/008.bathtub/008_0148.jpg
# 256_ObjectCategories/008.bathtub/008_0149.jpg
# 256_ObjectCategories/008.bathtub/008_0150.jpg
# 256_ObjectCategories/008.bathtub/008_0151.jpg
# 256_ObjectCategories/008.bathtub/008_0152.jpg
# 256_ObjectCategories/008.bathtub/008_0153.jpg
# 256_ObjectCategories/008.bathtub/008_0154.jpg
# 256_ObjectCategories/008.bathtub/008_0155.jpg
# 256_ObjectCategories/008.bathtub/008_0156.jpg
# 256_ObjectCategories/008.bathtub/008_0157.jpg
# 256_ObjectCategories/008.bathtub/008_0158.jpg
# 256_ObjectCategories/008.bathtub/008_0159.jpg
# 256_ObjectCategories/008.bathtub/008_0160.jpg
# 256_ObjectCategories/008.bathtub/008_0161.jpg
# 256_ObjectCategories/008.bathtub/008_0162.jpg
# 256_ObjectCategories/008.bathtub/008_0163.jpg
# 256_ObjectCategories/008.bathtub/008_0164.jpg
# 256_ObjectCategories/008.bathtub/008_0165.jpg
# 256_ObjectCategories/008.bathtub/008_0166.jpg
# 256_ObjectCategories/008.bathtub/008_0167.jpg
# 256_ObjectCategories/008.bathtub/008_0168.jpg
# 256_ObjectCategories/008.bathtub/008_0169.jpg
# 256_ObjectCategories/008.bathtub/008_0170.jpg
# 256_ObjectCategories/008.bathtub/008_0171.jpg
# 256_ObjectCategories/008.bathtub/008_0172.jpg
# 256_ObjectCategories/008.bathtub/008_0173.jpg
# 256_ObjectCategories/008.bathtub/008_0174.jpg
# 256_ObjectCategories/008.bathtub/008_0175.jpg
# 256_ObjectCategories/008.bathtub/008_0176.jpg
# 256_ObjectCategories/008.bathtub/008_0177.jpg
# 256_ObjectCategories/008.bathtub/008_0178.jpg
# 256_ObjectCategories/008.bathtub/008_0179.jpg
# 256_ObjectCategories/008.bathtub/008_0180.jpg
# 256_ObjectCategories/008.bathtub/008_0181.jpg
# 256_ObjectCategories/008.bathtub/008_0182.jpg
# 256_ObjectCategories/008.bathtub/008_0183.jpg
# 256_ObjectCategories/008.bathtub/008_0184.jpg
# 256_ObjectCategories/008.bathtub/008_0185.jpg
# 256_ObjectCategories/008.bathtub/008_0186.jpg
# 256_ObjectCategories/008.bathtub/008_0187.jpg
# 256_ObjectCategories/008.bathtub/008_0188.jpg
# 256_ObjectCategories/008.bathtub/008_0189.jpg
# 256_ObjectCategories/008.bathtub/008_0190.jpg
# 256_ObjectCategories/008.bathtub/008_0191.jpg
# 256_ObjectCategories/008.bathtub/008_0192.jpg
# 256_ObjectCategories/008.bathtub/008_0193.jpg
# 256_ObjectCategories/008.bathtub/008_0194.jpg
# 256_ObjectCategories/008.bathtub/008_0195.jpg
# 256_ObjectCategories/008.bathtub/008_0196.jpg
# 256_ObjectCategories/008.bathtub/008_0197.jpg
# 256_ObjectCategories/008.bathtub/008_0198.jpg
# 256_ObjectCategories/008.bathtub/008_0199.jpg
# 256_ObjectCategories/008.bathtub/008_0200.jpg
# 256_ObjectCategories/008.bathtub/008_0201.jpg
# 256_ObjectCategories/008.bathtub/008_0202.jpg
# 256_ObjectCategories/008.bathtub/008_0203.jpg
# 256_ObjectCategories/008.bathtub/008_0204.jpg
# 256_ObjectCategories/008.bathtub/008_0205.jpg
# 256_ObjectCategories/008.bathtub/008_0206.jpg
# 256_ObjectCategories/008.bathtub/008_0207.jpg
# 256_ObjectCategories/008.bathtub/008_0208.jpg
# 256_ObjectCategories/008.bathtub/008_0209.jpg
# 256_ObjectCategories/008.bathtub/008_0210.jpg
# 256_ObjectCategories/008.bathtub/008_0211.jpg
# 256_ObjectCategories/008.bathtub/008_0212.jpg
# 256_ObjectCategories/008.bathtub/008_0213.jpg
# 256_ObjectCategories/008.bathtub/008_0214.jpg
# 256_ObjectCategories/008.bathtub/008_0215.jpg
# 256_ObjectCategories/008.bathtub/008_0216.jpg
# 256_ObjectCategories/008.bathtub/008_0217.jpg
# 256_ObjectCategories/008.bathtub/008_0218.jpg
# 256_ObjectCategories/008.bathtub/008_0219.jpg
# 256_ObjectCategories/008.bathtub/008_0220.jpg
# 256_ObjectCategories/008.bathtub/008_0221.jpg
# 256_ObjectCategories/008.bathtub/008_0222.jpg
# 256_ObjectCategories/008.bathtub/008_0223.jpg
# 256_ObjectCategories/008.bathtub/008_0224.jpg
# 256_ObjectCategories/008.bathtub/008_0225.jpg
# 256_ObjectCategories/008.bathtub/008_0226.jpg
# 256_ObjectCategories/008.bathtub/008_0227.jpg
# 256_ObjectCategories/008.bathtub/008_0228.jpg
# 256_ObjectCategories/008.bathtub/008_0229.jpg
# 256_ObjectCategories/008.bathtub/008_0230.jpg
# 256_ObjectCategories/008.bathtub/008_0231.jpg
# 256_ObjectCategories/008.bathtub/008_0232.jpg
# 256_ObjectCategories/009.bear/
# 256_ObjectCategories/009.bear/009_0001.jpg
# 256_ObjectCategories/009.bear/009_0002.jpg
# 256_ObjectCategories/009.bear/009_0003.jpg
# 256_ObjectCategories/009.bear/009_0004.jpg
# 256_ObjectCategories/009.bear/009_0005.jpg
# 256_ObjectCategories/009.bear/009_0006.jpg
# 256_ObjectCategories/009.bear/009_0007.jpg
# 256_ObjectCategories/009.bear/009_0008.jpg
# 256_ObjectCategories/009.bear/009_0009.jpg
# 256_ObjectCategories/009.bear/009_0010.jpg
# 256_ObjectCategories/009.bear/009_0011.jpg
# 256_ObjectCategories/009.bear/009_0012.jpg
# 256_ObjectCategories/009.bear/009_0013.jpg
# 256_ObjectCategories/009.bear/009_0014.jpg
# 256_ObjectCategories/009.bear/009_0015.jpg
# 256_ObjectCategories/009.bear/009_0016.jpg
# 256_ObjectCategories/009.bear/009_0017.jpg
# 256_ObjectCategories/009.bear/009_0018.jpg
# 256_ObjectCategories/009.bear/009_0019.jpg
# 256_ObjectCategories/009.bear/009_0020.jpg
# 256_ObjectCategories/009.bear/009_0021.jpg
# 256_ObjectCategories/009.bear/009_0022.jpg
# 256_ObjectCategories/009.bear/009_0023.jpg
# 256_ObjectCategories/009.bear/009_0024.jpg
# 256_ObjectCategories/009.bear/009_0025.jpg
# 256_ObjectCategories/009.bear/009_0026.jpg
# 256_ObjectCategories/009.bear/009_0027.jpg
# 256_ObjectCategories/009.bear/009_0028.jpg
# 256_ObjectCategories/009.bear/009_0029.jpg
# 256_ObjectCategories/009.bear/009_0030.jpg
# tar: Unexpected EOF in archive
# tar: rmtlseek not stopped at a record boundary
# tar: Error is not recoverable: exiting now

# %%
from torchvision import datasets
from torch.utils.data import DataLoader, random_split
data_dir = "./256_ObjectCategories"

full_dataset = datasets.ImageFolder(root=data_dir, transform=transform_train)

# %%
# TODO: Use Caltech-256 dataset, you can download and load it through torchvision.datasets.ImageFolder
train_size = int(0.7 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=4)
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:627: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 4**
# 1) <blue>**model = None**</blue>: This line will load a <green>**pre-trained ResNet-18 model**</green> from the Torchvision library, which has been trained on the ImageNet dataset, allowing for transfer learning, when None is replaced with proper code.
# 2) <blue>**for param in model.parameters()**:</blue>: This loop iterates over all the parameters of the model, enabling modifications to their properties.
# 3) <blue>**param.requires_grad = None**</blue>: Inside the loop, this line will be used to <green>**freeze the model weights**</green> for all layers except the final fully connected layer. By setting requires_grad to False, gradients will not be calculated for these parameters during backpropagation, preventing them from being updated during training, when None is replace by proper code
# 4) <blue>**num_ftrs = model.fc.in_features**</blue>: This line retrieves the number of input features from the final fully connected layer of the model, which is necessary for modifying that layer.
# 5) <blue>**model.fc = nn.Linear(num_ftrs, 257)**</blue>: This modifies the final fully connected layer to output <green>**257 classes**</green>, corresponding to the number of classes in the Caltech-256 dataset, replacing the original output layer.
#
# Note: The placeholders **"None"** need to be replaced with the correct code.

# %%
# TODO: Replace None with correct code for loading a pretrained Resnet-18 model
model = models.resnet18(pretrained=True)

# Freeze the model weights except for the final layer
for param in model.parameters():
    # TODO: Freeze the model weights
    param.requires_grad = False

# Modify the final fully connected layer
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 257)  # 257 classes in Caltech-256
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 200MB/s]

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 5**
# 1) <blue>**model = None**</blue>: This line sends the <green>**model to the appropriate device**</green>, whether it's a GPU (if available) or a CPU, ensuring that the computations happen on the selected hardware, when None is replace with correct code.
# 2) <blue>**criterion = None**</blue>: Defines the <green>**loss function**</green> as cross-entropy loss, which is commonly used for multi-class classification problems, when None is replaced with the correct code.
# 3) <blue>**optimizer = None**</blue>: Initialize the <green>**Adam optimizer**</green> to update only the parameters of the modified final layer (model.fc). Set the learning rate to <green>**0.001**</green> to control the step size for each update during training.
#
# Note: The placeholders **"None"** need to be replaced with the correct code.

# %%
# TODO: Replace None with correct code to send model to device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
# Define loss function and optimizer
# TODO: Use a suitable loss criterion and optimizer with learning rate 0.001
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.fc.parameters(), lr=0.001)

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 6**
# 1) <blue>**train_model**</blue>: This function trains and evaluates the model for a specified number of <green>**epochs**</green>.
# 2) It <green>**alternates**</green> between training and testing phases, setting the model to <blue>**train() or eval()**</blue> mode accordingly.
# 3) <blue>**images = None, labels = None**</blue>: Images and labels are moved to the <green>**device (CPU or GPU)**</green>.
# 4) <blue>**Backpropagation and Optimization**</blue>: Gradients are calculated using backpropagation, and the optimizer <green>**updates the model parameters**</green> based on these gradients.
#
# Note: The placeholders **"None"** need to be replaced with the correct code.

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# Train and evaluate the model
def train_model(model, criterion, optimizer, num_epochs=10):
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and testing phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
                dataloader = train_loader
            else:
                model.eval()   # Set model to evaluation mode
                dataloader = test_loader

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloader:
                # TODO: Move images and labels to the device
                images = inputs.to(device) # Replace None with the correct code
                labels = labels.to(device)

                # Zero the parameter gradients
                optimizer.zero_grad()

                # Forward
                with torch.set_grad_enabled(phase == 'train'):

                    # TODO: Forward Pass
                    outputs = model(images)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels) # Replace None with the correct code to find error between labels and outputs

                    # Backward + optimize only in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # Statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloader.dataset)
            epoch_acc = running_corrects.double() / len(dataloader.dataset)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

    return model


# Fine-tune the model
fine_tuned_model = train_model(model, criterion, optimizer, num_epochs=5)
# Out:
# Epoch 0/4
# ----------
# train Loss: 1.3413 Acc: 0.6344
# test Loss: 1.1448 Acc: 0.7037
# Epoch 1/4
# ----------
# train Loss: 0.9715 Acc: 0.7576
# test Loss: 0.7842 Acc: 0.8272
# Epoch 2/4
# ----------
# train Loss: 0.7879 Acc: 0.7762
# test Loss: 0.6910 Acc: 0.8642
# Epoch 3/4
# ----------
# train Loss: 0.6706 Acc: 0.8278
# test Loss: 0.6012 Acc: 0.8488
# Epoch 4/4
# ----------
# train Loss: 0.6054 Acc: 0.8371
# test Loss: 0.6147 Acc: 0.8333

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 7**
# The provided code consists of three functions designed for model evaluation and visualization:
# 1) <blue>**visualize_predictions**</blue>: This function takes a <green>**trained model**</green> and a <green>**dataloader**</green>, then displays a set number of images with their predicted labels. It sets the model to <blue>**evaluation mode**</blue> and processes the input data without <green>**calculating gradients**</green> (using <blue>**torch.no_grad()**</blue>), which speeds up the evaluation. After moving the inputs to the correct device, it computes predictions using a forward pass through the model and visualizes the results in a subplot.
# 2) <blue>**denormalize**</blue>: This utility function converts a <blue>**normalized image tensor**</blue> back to its <blue>**original form**</blue> by <green>**reversing the normalization process**</green>. It applies the <green>**mean**</green> and <green>**standard deviation**</green> used during image preprocessing, ensuring the values are scaled back into the range suitable for visualization (<blue>**clipped between 0 and 1**</blue>).
# 3) <blue>**make_map_classes**</blue>: This function generates a <blue>**dictionary mapping class indices**</blue> to their corresponding class names. It reads the folder names (assuming they follow a specific naming convention), extracts the index and name of each class, and sorts them in the correct order for use in classification tasks.

# %%
# Evaluate the performance of the model before and after fine-tuning
# Function to visualize images and their predictions
def visualize_predictions(model, dataloader, num_images=2):
    model.eval()  # Set the model to evaluation mode
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for inputs, labels in dataloader:
            # TODO: Move images to the device
            inputs = inputs.to(device)

            # TODO: Forward Pass = Get Predictions
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for i in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images, 2, images_so_far)
                ax.axis('off')
                ax.set_title(f'Predicted: {preds[i].item()}')
                img = inputs.cpu().data[i]
                img = img.permute(1, 2, 0).numpy()  # Convert from Tensor format
                img = np.clip(img, 0, 1)  # Clip the values for display
                ax.imshow(img)

                if images_so_far == num_images:
                    return

# Function to denormalize the image for visualization
def denormalize(image_tensor):
    # Means and stds used for normalization
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = image_tensor.permute(1, 2, 0).numpy()  # Convert tensor to HWC
    image = std * image + mean  # Denormalize
    image = np.clip(image, 0, 1)  # Clip values to be in [0, 1] range
    return image


def make_map_classes(path):
    classes_dir = os.listdir(path)
    classes_dir.sort()
    classes_dict = {}
    for c in classes_dir:
        index = int(c[:3])
        name = c[4:]
        classes_dict[index] = name

    return classes_dict

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 8**
# 1) This function, <blue>**compare_predictions**</blue>, is designed to visually compare the predictions made by a <green>**pre-trained model**</green> and a <green>**fine-tuned version**</green> of that model, helping to assess the impact of fine-tuning. It takes in both models, a dataloader, the directory path containing class labels, and the number of images to display.
# 2) <blue>**Model Evaluation Mode**</blue>: Both the <green>**pre-trained**</green> and <green>**fine-tuned models**</green> are set to <green>**evaluation mode**</green> using <blue>**.eval()**</blue>. This ensures that no gradients are calculated during the forward pass, making inference faster and memory-efficient.
# 3)  The TODO lines highlight the need to move the <blue>**input images (inputs)**</blue> to the appropriate device (<green>**CPU**</green> or <green>**GPU**</green>), though this is left as an implementation detail.
# 4) The first subplot shows the prediction from the <blue>**pre-trained model**</blue> along with its <green>**corresponding class name (retrieved from**</green> the <blue>**classes_dict dictionary**</blue>). The second subplot shows the prediction from the <blue>**fine-tuned model**</blue> for comparison. This allows easy visual inspection of how fine-tuning has affected the model's ability to make accurate predictions.

# %%
# Function to compare predictions of non-finetuned and finetuned models
def compare_predictions(pretrained_model, finetuned_model, dataloader, path_dir, num_images=5):
    pretrained_model.eval()
    finetuned_model.eval()

    images_shown = 0
    classes_dict = make_map_classes(path_dir)

    with torch.no_grad():
        for inputs, labels in dataloader:
            # TODO: Move inputs to device
            inputs = inputs.to(device)

            # Predictions from pre-trained model (without fine-tuning)
            # TODO: Calculate outputs using forward pass of pretrained model
            pre_outputs = pretrained_model(inputs)
            _, pre_preds = torch.max(pre_outputs, 1)

            # Predictions from fine-tuned model
            # TODO: Calculate the outputs using the gforward pass of the finetuned model
            fin_outputs = finetuned_model(inputs)
            _, fin_preds = torch.max(fin_outputs, 1)

            for i in range(inputs.size()[0]):
                if images_shown == num_images:
                    return  # Stop after showing num_images
                images_shown += 1

                img = denormalize(inputs.cpu().data[i])

                plt.figure(figsize=(10, 4))

                # Show pre-trained model's prediction
                plt.title(
    f'Pre-trained Prediction: {pre_preds[i].item()} : {classes_dict.get(pre_preds[i].item(), "Unknown")}'
)
                # Show fine-tuned model's prediction
                plt.subplot(1, 2, 2)
                plt.imshow(img)
                plt.title(f'Fine-tuned Prediction: {fin_preds[i].item()} : {classes_dict[fin_preds[i].item()+1]}')
                plt.axis('off')

                plt.show()

# %% [markdown]
# <style>
# blue {
#   color: skyblue;
# }
#
# red {
#   color: red;
# }
#
# green {
#   color: lightgreen;
# }
# </style>
#
# ### **Step - 9**
# This code snippet is used to <green>**evaluate**</green> and visualize the predictions of both a <blue>**pre-trained**</blue> and a <blue>**fine-tuned model**</blue> on a set of example images. It compares the predictions side by side to assess the <green>**performance improvements**</green> brought by fine-tuning.

# %%
label = classes_dict.get(pre_preds[i].item(), f"Class {pre_preds[i].item()}")
plt.title(f'Pre-trained Prediction: {label}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1188857858.py in <cell line: 0>()
# ----> 1 label = classes_dict.get(pre_preds[i].item(), f"Class {pre_preds[i].item()}")
#       2 plt.title(f'Pre-trained Prediction: {label}')
#
# NameError: name 'classes_dict' is not defined

# %%
print(min(classes_dict.keys()), max(classes_dict.keys()), len(classes_dict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-97783924.py in <cell line: 0>()
# ----> 1 print(min(classes_dict.keys()), max(classes_dict.keys()), len(classes_dict))
#
# NameError: name 'classes_dict' is not defined

# %%
plt.title(f'Pre-trained Prediction: {pre_preds[i].item()} : {classes_dict.get(pre_preds[i].item(), "Unknown")}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2526839400.py in <cell line: 0>()
# ----> 1 plt.title(f'Pre-trained Prediction: {pre_preds[i].item()} : {classes_dict.get(pre_preds[i].item(), "Unknown")}')
#
# NameError: name 'pre_preds' is not defined

# %%
# Evaluate and visualize predictions
print("Comparing predictions of pre-trained and fine-tuned models on example images...")

# Ensure both models have the same structure (so, freeze layers for pretrained_model)
pretrained_model = models.resnet18(pretrained=True)
pretrained_model.fc = nn.Linear(pretrained_model.fc.in_features, 257)
pretrained_model = pretrained_model.to(device)

# Compare predictions using a couple of test images
# TODO: Fill in the path of the 256_ObjectCategories directory in the path variable below.
path_to256_ObjectCategories_dir = '256_ObjectCategories'
compare_predictions(pretrained_model, fine_tuned_model, test_loader, path_to256_ObjectCategories_dir ,num_images=10)
# Out:
# Comparing predictions of pre-trained and fine-tuned models on example images...

# %% [markdown]
# ## For students attempting Advanced Level (optional for basic)

# %% [markdown]
# ### **Step - 10**
#
# #### **Exploring Learning Rate Scheduling and Optimization Strategies**
#
# This step delves deeper into fine-tuning by exploring advanced techniques for optimizing the training process. Instead of using a fixed learning rate, you can implement learning rate scheduling. This involves dynamically adjusting the learning rate during training, which can help the model converge more effectively. Common strategies include step decay, exponential decay, or using reduce-on-LRPatience.
#
# Furthermore, you can experiment with different optimization algorithms beyond Adam, such as SGD with momentum, RMSprop, or even more advanced adaptive optimizers like RAdam or Lookahead. Each optimizer has its own characteristics and can perform differently depending on the dataset and model architecture.
#
# By implementing and comparing various learning rate schedules and optimization strategies, you can gain a deeper understanding of how these factors impact the fine-tuning process and model performance.

# %%
# Define a new optimizer (e.g., SGD)
from torch.optim import SGD
new_optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)

# Define a learning rate scheduler (e.g., StepLR)
from torch.optim import lr_scheduler
new_scheduler = lr_scheduler.StepLR(new_optimizer, step_size=7, gamma=0.1)

# Modify the train_model function to include the scheduler
def train_model_with_scheduler(model, criterion, optimizer, scheduler, num_epochs=10):
    for epoch in range(num_epochs):
        print(f'\nEpoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and testing phase
        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
                dataloader = train_loader
            else:
                model.eval()   # Set model to evaluation mode
                dataloader = test_loader

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data
            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                # Forward pass
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # Backprop + optimize only during training
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # ✅ Always accumulate stats for both train & test
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).item()

            # Compute average loss & accuracy
            epoch_loss = running_loss / len(dataloader.dataset)
            epoch_acc = running_corrects / len(dataloader.dataset)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

        # Step the scheduler after each epoch
        scheduler.step()

    return model


# Train the model with the new optimizer and scheduler
fine_tuned_model_with_scheduler = train_model_with_scheduler(
    model, criterion, new_optimizer, new_scheduler, num_epochs=5
)
# Out:
# Epoch 0/4
# ----------
# train Loss: 0.4701 Acc: 0.8742
# test Loss: 0.4364 Acc: 0.8611
#
# Epoch 1/4
# ----------
# train Loss: 0.4323 Acc: 0.8821
# test Loss: 0.4611 Acc: 0.8457
#
# Epoch 2/4
# ----------
# train Loss: 0.4297 Acc: 0.8702
# test Loss: 0.4637 Acc: 0.8827
#
# Epoch 3/4
# ----------
# train Loss: 0.4112 Acc: 0.8927
# test Loss: 0.4318 Acc: 0.8827
#
# Epoch 4/4
# ----------
# train Loss: 0.3878 Acc: 0.9060
# test Loss: 0.4081 Acc: 0.8951

# %% [markdown]
# ### **Step - 11**
#
# #### **Investigating Different Freezing Strategies and Layer Unfreezing**
#
# In the initial fine-tuning steps, we froze all layers except the final fully connected layer. However, depending on the dataset and the similarity between the pre-training task and the fine-tuning task, you might benefit from unfreezing more layers or using different freezing strategies.
#
# This step encourages you to experiment with unfreezing earlier layers of the pre-trained model. While unfreezing all layers might lead to overfitting on smaller datasets, selectively unfreezing blocks of layers or even individual layers can allow the model to learn more task-specific features from the earlier convolutional layers.
#
# You can also explore gradual unfreezing, where you start by unfreezing only the last few layers and then progressively unfreeze earlier layers as training progresses. This can help stabilize training and prevent catastrophic forgetting of the pre-trained knowledge. By comparing the performance of models fine-tuned with different freezing strategies, you can determine the optimal approach for your specific task.

# %%
# Unfreeze the last few layers (e.g., layer4 and the fully connected layer)
def unfreeze_last_layers(model, num_layers_to_unfreeze=2):
    # Unfreeze the fully connected layer (already unfrozen in Step 4, but good to be explicit)
    for param in model.fc.parameters():
        param.requires_grad = True

    # Unfreeze the last 'num_layers_to_unfreeze' convolutional layers
    # ResNet-18 has layers: conv1, layer1, layer2, layer3, layer4, fc
    # We want to unfreeze layer4 and potentially layer3
    unfrozen_layers = [model.layer4, model.layer3] # Add more layers to this list as needed

    for i in range(min(num_layers_to_unfreeze, len(unfrozen_layers))):
        for param in unfrozen_layers[i].parameters():
            param.requires_grad = True

# Unfreeze all layers (use with caution, especially on small datasets)
def unfreeze_all_layers(model):
    for param in model.parameters():
        param.requires_grad = True

# Example usage:
# Assuming 'model' is the pretrained ResNet-18 loaded in Step 4
# First, freeze all layers as in Step 4
# for param in model.parameters():
#     param.requires_grad = False

# Then, choose a strategy:
# unfreeze_last_layers(model, num_layers_to_unfreeze=2) # Unfreeze layer4 and layer3
# OR
# unfreeze_all_layers(model) # Unfreeze all layers

# After unfreezing, you would re-define your optimizer to include the newly unfrozen layers
# new_optimizer_for_unfrozen = optim.Adam(model.parameters(), lr=0.0001) # Lower learning rate is often recommended
# Then train the model again with the new optimizer
# fine_tuned_model_unfrozen = train_model(model, criterion, new_optimizer_for_unfrozen, num_epochs=5)

# You would then evaluate and compare this model's performance as done in Step 9.
# Train and Evaluate the new model on the previously given dataset.

# %% [markdown]
# ### **Evaluatory Task (For Advanced Level)**
#
# Now that you have explored different optimization strategies, learning rate scheduling, and layer unfreezing techniques, try combining these concepts to train a new model.
#
# 1.  **Choose an unfreezing strategy:** Decide which layers you want to unfreeze based on your understanding from Step 11. You can use the provided `unfreeze_last_layers` or `unfreeze_all_layers` functions, or experiment with unfreezing specific layers.
# 2.  **Select an optimizer and learning rate scheduler:** Choose an optimizer (e.g., SGD, Adam with a different learning rate) and a learning rate scheduler (e.g., StepLR, ReduceLROnPlateau) from Step 10.
# 3.  **Combine and train:** Integrate your chosen unfreezing strategy, optimizer, and scheduler into a training loop. You can adapt the `train_model_with_scheduler` function provided in Step 10.
# 4.  **Evaluate and compare:** After training, evaluate the performance of your new model using the `visualize_predictions` and `compare_predictions` functions from Step 7 and 8. Compare its performance to the models trained in the previous steps to see the impact of your chosen techniques.
#
# Experiment with different combinations of unfreezing strategies, optimizers, and schedulers to find the best approach for fine-tuning the ResNet model on the Caltech-256 dataset.
#
# You have to write code in a new code cell with the given modifications and evaluate the model again. You can use the previous format of code written. Also include a short written discussion summarizing your findings.

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

print("--- Starting Advanced Level Task ---")

adv_model = models.resnet18(pretrained=True)
num_ftrs = adv_model.fc.in_features
adv_model.fc = nn.Linear(num_ftrs, 257)
adv_model = adv_model.to(device)

for param in adv_model.parameters():
    param.requires_grad = False

print("Unfreezing layers: fc, layer4, layer3")
unfreeze_last_layers(adv_model, num_layers_to_unfreeze=2)

adv_optimizer = optim.AdamW(adv_model.parameters(), lr=1e-4)

# --- THIS IS THE CORRECTED LINE (verbose=True has been removed) ---
adv_scheduler = ReduceLROnPlateau(adv_optimizer, 'min', patience=2, factor=0.1)

def train_model_advanced(model, criterion, optimizer, scheduler, num_epochs=10):
    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        for phase in ['train', 'test']:
            if phase == 'train':
                model.train()
                dataloader = train_loader
            else:
                model.eval()
                dataloader = test_loader

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in dataloader:
                inputs = inputs.to(device)
                labels = labels.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(dataloader.dataset)
            epoch_acc = running_corrects.double() / len(dataloader.dataset)

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            if phase == 'test':
                scheduler.step(epoch_loss)

    return model

print("\nTraining advanced model...")
advanced_finetuned_model = train_model_advanced(adv_model, criterion, adv_optimizer, adv_scheduler, num_epochs=5)

print("\nComparing Pre-trained vs. Advanced Fine-Tuned Model...")
compare_predictions(pretrained_model, advanced_finetuned_model, test_loader, path_to256_ObjectCategories_dir, num_images=10)

print("--- Advanced Level Task Complete ---")
# Out:
# --- Starting Advanced Level Task ---
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Unfreezing layers: fc, layer4, layer3
#
# Training advanced model...
# Epoch 0/4
# ----------
# train Loss: 3.2522 Acc: 0.5192
# test Loss: 1.4673 Acc: 0.7963
# Epoch 1/4
# ----------
# train Loss: 0.8924 Acc: 0.8331
# test Loss: 0.7964 Acc: 0.8364
# Epoch 2/4
# ----------
# train Loss: 0.4848 Acc: 0.8834
# test Loss: 0.5968 Acc: 0.8765
# Epoch 3/4
# ----------
# train Loss: 0.3654 Acc: 0.9046
# test Loss: 0.5365 Acc: 0.8796
# Epoch 4/4
# ----------
# train Loss: 0.3566 Acc: 0.9007
# test Loss: 0.4966 Acc: 0.8858
#
# Comparing Pre-trained vs. Advanced Fine-Tuned Model...
# --- Advanced Level Task Complete ---
